# %%
#! pip install osmnx

# %% [markdown]
# This code extracts building and road data from OpenStreetMap using the osmnx library and plots the buildings and roads on a map using matplotlib.
#
# First, the necessary libraries are imported: osmnx for accessing OpenStreetMap data and converting it to networkx graphs, geopandas for handling geographic data, pandas for data manipulation, networkx for network analysis, and matplotlib for plotting.
#
# Next, the tags to filter the OpenStreetMap data are defined. In this case, the code is extracting buildings, so the tag is set to {'building':True}.
#
# The center point and distance for extracting the data are then defined. The center point is set to the coordinates (57.1497, -2.0943) and the distance is set to 100 meters.
#
# The code then extracts buildings data from OpenStreetMap using the features_from_point function from osmnx and converts the data to a GeoDataFrame using geopandas. The first few rows of the GeoDataFrame are displayed using the head() function.
#
# The code then extracts roads data from OpenStreetMap using the graph_from_point function from osmnx and converts the data to a GeoDataFrame using osmnx. The first few rows of the GeoDataFrame are displayed using the head() function.
#
# Finally, the code plots the buildings and roads data on a map using matplotlib. The buildings are plotted in the original color and the roads are plotted in red. The plot is displayed using the show() function.

# %%
# Import necessary libraries
# osmnx is used for accessing OpenStreetMap data and converting it to networkx graphs
# geopandas is used for handling geographic data
# pandas is used for data manipulation
# networkx is used for network analysis
# matplotlib is used for plotting

import osmnx as ox
import geopandas as gpd
import pandas as pd
import networkx as nx
import matplotlib.pyplot as plt

# %%
# Define the tags to filter the OpenStreetMap data
tags = tags={'building':True}

# %%
# Define the center point and distance for extracting the data
center_point = (57.1497,-2.0943)
# and the extent of the area
dist = 100

# %%
# Extract buildings data from OpenStreetMap
buildings = ox.features_from_point(center_point, tags, dist)

# Convert the buildings data to a GeoDataFrame
buildings_gdf = gpd.GeoDataFrame(buildings, geometry='geometry')

# %%
# Display the first few rows of the GeoDataFrame
buildings_gdf.head()
# Out:
#                                                              geometry  \
# element  id
# relation 5135449    POLYGON ((-2.09646 57.14981, -2.09636 57.14988...
# way      87956024   POLYGON ((-2.09542 57.15044, -2.09538 57.15048...
#          313985775  POLYGON ((-2.09333 57.14896, -2.09298 57.14898...
#          313986637  POLYGON ((-2.09336 57.14879, -2.09334 57.14871...
#          313986640  POLYGON ((-2.09339 57.14892, -2.09336 57.14879...
#
#                    addr:city addr:housenumber addr:postcode  \
# element  id
# relation 5135449         NaN              NaN           NaN
# way      87956024   Aberdeen               10      AB24 5AS
#          313985775  Aberdeen               28      AB24 5AX
#          313986637       NaN               20           NaN
#          313986640       NaN               26           NaN
#
#                           addr:street     alt_name        brand  \
# element  id
# relation 5135449                  NaN          NaN          NaN
# way      87956024   West North Street  Premier Inn  Premier Inn
#          313985775        King Street          NaN          NaN
#          313986637        King Street          NaN          NaN
#          313986640        King Street          NaN          NaN
#
#                    brand:wikidata brand:wikipedia    building  ... layer  \
# element  id                                                    ...
# relation 5135449              NaN             NaN  university  ...   NaN
# way      87956024        Q2108626  en:Premier Inn       hotel  ...   NaN
#          313985775            NaN             NaN   cathedral  ...   NaN
#          313986637            NaN             NaN  apartments  ...   NaN
#          313986640            NaN             NaN  apartments  ...   NaN
#
#                    capacity vacant:amenity building:min_level          type  \
# element  id
# relation 5135449        NaN            NaN                NaN  multipolygon
# way      87956024       NaN            NaN                NaN           NaN
#          313985775      NaN            NaN                NaN           NaN
#          313986637      NaN            NaN                NaN           NaN
#          313986640      NaN            NaN                NaN           NaN
#
#                    HS_ref  heritage:operator    historic              name:gd  \
# element  id
# relation 5135449    20096  Historic Scotland  university  Colaiste Mharischal
# way      87956024     NaN                NaN         NaN                  NaN
#          313985775    NaN                NaN         NaN                  NaN
#          313986637    NaN                NaN         NaN                  NaN
#          313986640    NaN                NaN         NaN                  NaN
#
#                                  occupier
# element  id
# relation 5135449    Aberdeen City Council
# way      87956024                     NaN
#          313985775                    NaN
#          313986637                    NaN
#          313986640                    NaN
#
# [5 rows x 68 columns]

# %%
# Extract roads data from OpenStreetMap
roads = ox.graph_from_point(center_point=center_point,dist=dist, network_type='all')

# %%
# Convert the roads data to a GeoDataFrame
roads_gdf = ox.graph_to_gdfs(roads, nodes=False)

# %%
# Display the first few rows of the GeoDataFrame
roads_gdf.head()
# Out:
#                                            osmid   highway lanes maxspeed  \
# u        v           key
# 17420460 1504382237  0                   5216960   primary     2   30 mph
#          36683821    0                 263489146   primary     3   30 mph
#          11179203031 0    [315947545, 315947546]  tertiary     3   20 mph
# 36683821 17420460    0                 263489146   primary     3   30 mph
#          11195856364 0                1315992592   primary     2   30 mph
#
#                                        name  oneway   ref width reversed  \
# u        v           key
# 17420460 1504382237  0    West North Street    True   A96   7.3    False
#          36683821    0          King Street   False  A956   NaN    False
#          11179203031 0          King Street   False   NaN   NaN     True
# 36683821 17420460    0          King Street   False  A956   NaN     True
#          11195856364 0    East North Street    True  A956   NaN    False
#
#                              length  \
# u        v           key
# 17420460 1504382237  0    13.076209
#          36683821    0    13.763303
#          11179203031 0    70.779342
# 36683821 17420460    0    13.763303
#          11195856364 0    19.877577
#
#                                                                    geometry  \
# u        v           key
# 17420460 1504382237  0    LINESTRING (-2.09376 57.14984, -2.09397 57.14987)
#          36683821    0     LINESTRING (-2.09376 57.14984, -2.0938 57.14996)
#          11179203031 0    LINESTRING (-2.09376 57.14984, -2.09374 57.149...
# 36683821 17420460    0     LINESTRING (-2.0938 57.14996, -2.09376 57.14984)
#          11195856364 0     LINESTRING (-2.0938 57.14996, -2.09348 57.14992)
#
#                          service access
# u        v           key
# 17420460 1504382237  0       NaN    NaN
#          36683821    0       NaN    NaN
#          11179203031 0       NaN    NaN
# 36683821 17420460    0       NaN    NaN
#          11195856364 0       NaN    NaN

# %%
# Plot the buildings and roads data
fig, ax = plt.subplots(figsize=(8, 8))
buildings_gdf.plot(ax=ax)
roads_gdf.plot(ax=ax,color='red')
plt.show()
